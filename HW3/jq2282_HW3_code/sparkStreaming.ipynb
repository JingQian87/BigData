# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Columbia EECS E6893 Big Data Analytics
"""
This module is the spark streaming analysis process.


Usage:
    If used with dataproc:
        gcloud dataproc jobs submit pyspark --cluster <Cluster Name> twitterHTTPClient.py

    Create a dataset in BigQurey first using
        bq mk bigdata_sparkStreaming

    Remeber to replace the bucket with your own bucket name


Todo:
    1. hashtagCount: calculate accumulated hashtags count
    2. wordCount: calculate word count every 60 seconds
        the word you should track is listed below.
    3. save the result to google BigQuery

"""

from pyspark import SparkConf,SparkContext
from pyspark.streaming import StreamingContext
from pyspark.sql import Row,SQLContext
import sys
import requests
import time
import subprocess
import re
from google.cloud import bigquery

# global variables
bucket = "bucket-hw3"    # TODO : replace with your own bucket name
output_directory_hashtags = 'gs://{}/hadoop/tmp/bigquery/pyspark_output/hashtagsCount'.format(bucket)
output_directory_wordcount = 'gs://{}/hadoop/tmp/bigquery/pyspark_output/wordcount'.format(bucket)

# output table and columns name
output_dataset = 'datasetHW3'                     #the name of your dataset in BigQuery
output_table_hashtags = 'hashtags'
columns_name_hashtags = ['hashtags', 'count']
output_table_wordcount = 'wordcount'
columns_name_wordcount = ['word', 'count', 'time']

# parameter
IP = 'localhost'    # ip port
PORT = 9001       # port

STREAMTIME = 600          # time that the streaming process runs

WORD = ['data', 'spark', 'ai', 'movie', 'good']     #the words you should filter and do word count

# %%
def aggregate_tags_count(new_values, total_sum):
    return sum(new_values) + (total_sum or 0)
    
def hashtagCount(words):
    """
    Calculate the accumulated hashtags count sum from the beginning of the stream
    and sort it by descending order of the count.
    Ignore case sensitivity when counting the hashtags:
        "#Ab" and "#ab" is considered to be a same hashtag
    You have to:
    1. Filter out the word that is hashtags.
       Hashtag usually start with "#" and followed by a series of alphanumeric
    2. map (hashtag) to (hashtag, 1)
    3. sum the count of current DStream state and previous state
    4. transform unordered DStream to a ordered Dstream
    Args:
        dstream(DStream): stream of real time tweets
    Returns:
        DStream Object with inner structure (hashtag, count)
    """

    # TODO: insert your code here
    import re
    tagCounts = words.filter(lambda word: word.lower().startswith("#") and re.match('^[a-zA-Z0-9]+$',word[1:])).\
                map(lambda word:(word.lower(),1))
    tagCounts = tagCounts.updateStateByKey(aggregate_tags_count)
    return tagCounts.transform(lambda rdd: rdd.sortBy(lambda x: x[1], ascending=False))

# %%
def wordCount(words):
    """
    Calculte the count of 5 sepcial words in 60 seconds for every 60 seconds (window no overlap)
    Your should:
    1. filter the words, case insensitive.
    2. count the word during a special window size
    3. add a time related mark to the output of each window, ex: a datetime type
    Hints:
        You can take a look at reduceByKeyAndWindow transformation
        Dstream is a series of rdd, each RDD in a DStream contains data from a certain interval
        You may want to take a look of transform transformation of DStream when trying to add a time
    Args:
        dstream(DStream): stream of real time tweets
    Returns:
        DStream Object with inner structure (word, count, time)
    """

    # TODO: insert your code here
    selected = words.filter(lambda x: any(word == x.lower() for word in WORD)).\
                map(lambda word:(word.lower(),1))
    counts = selected.reduceByKeyAndWindow(lambda x, y: x + y, lambda x, y: x - y, 60, 60)
    return counts.transform(lambda time, rdd: rdd.map(lambda x: (x[0],x[1],time)))

# %%
# Helper functions
def saveToStorage(rdd, output_directory, columns_name, mode):
    """
    Save each RDD in this DStream to google storage
    Args:
        rdd: input rdd
        output_directory: output directory in google storage
        columns_name: columns name of dataframe
        mode: mode = "overwrite", overwirte the file
              mode = "append", append data to the end of file
    """
    if not rdd.isEmpty():
        (rdd.toDF( columns_name ) \
        .write.save(output_directory, format="json", mode=mode))


def saveToBigQuery(sc, output_dataset, output_table, directory):
    """
    Put temp streaming json files in google storage to google BigQuery
    and clean the output files in google storage
    """
    files = directory + '/part-*'
    subprocess.check_call(
        'bq load --source_format NEWLINE_DELIMITED_JSON '
        '--replace '
        '--autodetect '
        '{dataset}.{table} {files}'.format(
            dataset=output_dataset, table=output_table, files=files
        ).split())
    output_path = sc._jvm.org.apache.hadoop.fs.Path(directory)
    output_path.getFileSystem(sc._jsc.hadoopConfiguration()).delete(
        output_path, True)

# %%
# Spark settings
conf = SparkConf()
conf.setMaster('local[2]')
conf.setAppName("TwitterStreamApp")

# create spark context with the above configuration
#sc = SparkContext(conf=conf)
sc = SparkContext.getOrCreate()
sc.setLogLevel("ERROR")

# create sql context, used for saving rdd
sql_context = SQLContext(sc)

# create the Streaming Context from the above spark context with batch interval size 5 seconds
ssc = StreamingContext(sc, 5)
# setting a checkpoint to allow RDD recovery
ssc.checkpoint("~/checkpoint_TwitterApp")

# read data from port 9001
dataStream = ssc.socketTextStream(IP, PORT)
#dataStream.pprint()

words = dataStream.flatMap(lambda line: line.split(" "))

# calculate the accumulated hashtags count sum from the beginning of the stream
topTags = hashtagCount(words)
topTags.pprint()

# Calculte the word count during each time period 60s
wordCount = wordCount(words)
wordCount.pprint()

def saveTopTags(rdd):
    saveToStorage(rdd, output_directory_hashtags, columns_name_hashtags, "overwrite")
topTags.foreachRDD(saveTopTags)

def saveWordCounts(rdd):
    saveToStorage(rdd, output_directory_wordcount, columns_name_wordcount, "append")
wordCount.foreachRDD(saveWordCounts)

# start streaming process, wait for 600s and then stop.
ssc.start()
time.sleep(STREAMTIME)
ssc.stop(stopSparkContext=False, stopGraceFully=True)

# put the temp result in google storage to google BigQuery
saveToBigQuery(sc, output_dataset, output_table_hashtags, output_directory_hashtags)
saveToBigQuery(sc, output_dataset, output_table_wordcount, output_directory_wordcount)
# Out:
# -------------------------------------------
# Time: 2019-10-31 13:24:55
# -------------------------------------------
# ('#bms', 1)
#
# -------------------------------------------
# Time: 2019-10-31 13:25:00
# -------------------------------------------
# ('#atlee', 4)
# ('#sanki', 3)
# ('#shahrukhkhan', 2)
# ('#srk', 2)
# ('#bms', 1)
# ('#ongseongwu', 1)
# ('#countdowntohalloween', 1)
# ('#sweepstakes', 1)
# ('#taeyeon', 1)
# ('#2', 1)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:25:05
# -------------------------------------------
# ('#bigil', 11)
# ('#atlee', 6)
# ('#sanki', 4)
# ('#shahrukhkhan', 3)
# ('#srk', 3)
# ('#ai', 3)
# ('#ongseongwu', 2)
# ('#fintech', 2)
# ('#bms', 1)
# ('#countdowntohalloween', 1)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:25:10
# -------------------------------------------
# ('#bigil', 15)
# ('#atlee', 6)
# ('#sanki', 4)
# ('#ai', 4)
# ('#shahrukhkhan', 3)
# ('#srk', 3)
# ('#ongseongwu', 2)
# ('#fintech', 2)
# ('#petta', 2)
# ('#viswasam', 2)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:25:15
# -------------------------------------------
# ('#bigil', 17)
# ('#atlee', 8)
# ('#sanki', 5)
# ('#shahrukhkhan', 4)
# ('#srk', 4)
# ('#ai', 4)
# ('#ongseongwu', 2)
# ('#fintech', 2)
# ('#petta', 2)
# ('#viswasam', 2)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:25:20
# -------------------------------------------
# ('#bigil', 22)
# ('#atlee', 9)
# ('#sanki', 6)
# ('#srk', 5)
# ('#ai', 5)
# ('#shahrukhkhan', 4)
# ('#viswasam', 3)
# ('#ongseongwu', 2)
# ('#fintech', 2)
# ('#hvinoth', 2)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:25:25
# -------------------------------------------
# ('#bigil', 24)
# ('#atlee', 9)
# ('#sanki', 6)
# ('#srk', 6)
# ('#shahrukhkhan', 5)
# ('#ai', 5)
# ('#viswasam', 4)
# ('#hvinoth', 3)
# ('#ongseongwu', 2)
# ('#fintech', 2)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:25:30
# -------------------------------------------
# ('#bigil', 27)
# ('#atlee', 10)
# ('#shahrukhkhan', 6)
# ('#sanki', 6)
# ('#srk', 6)
# ('#viswasam', 6)
# ('#hvinoth', 5)
# ('#ai', 5)
# ('#ongseongwu', 2)
# ('#fintech', 2)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:25:35
# -------------------------------------------
# ('#bigil', 32)
# ('#atlee', 10)
# ('#shahrukhkhan', 6)
# ('#sanki', 6)
# ('#srk', 6)
# ('#ai', 6)
# ('#viswasam', 6)
# ('#hvinoth', 5)
# ('#iot', 3)
# ('#ongseongwu', 2)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:25:40
# -------------------------------------------
# ('#bigil', 35)
# ('#atlee', 11)
# ('#sanki', 8)
# ('#srk', 8)
# ('#viswasam', 8)
# ('#hvinoth', 7)
# ('#shahrukhkhan', 6)
# ('#ai', 6)
# ('#bigdata', 3)
# ('#halloween2019', 3)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:25:45
# -------------------------------------------
# ('#bigil', 43)
# ('#atlee', 11)
# ('#viswasam', 9)
# ('#hvinoth', 8)
# ('#sanki', 8)
# ('#srk', 8)
# ('#shahrukhkhan', 6)
# ('#ai', 6)
# ('#iot', 4)
# ('#bigdata', 3)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:25:50
# -------------------------------------------
# ('#bigil', 49)
# ('#atlee', 12)
# ('#srk', 12)
# ('#shahrukhkhan', 9)
# ('#sanki', 9)
# ('#viswasam', 9)
# ('#hvinoth', 8)
# ('#ai', 8)
# ('#bigdata', 4)
# ('#iot', 4)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:25:50
# -------------------------------------------
# ('movie', 176, datetime.datetime(2019, 10, 31, 13, 25, 50))
# ('ai', 9, datetime.datetime(2019, 10, 31, 13, 25, 50))
# ('good', 3, datetime.datetime(2019, 10, 31, 13, 25, 50))
# ('spark', 17, datetime.datetime(2019, 10, 31, 13, 25, 50))
# ('data', 4, datetime.datetime(2019, 10, 31, 13, 25, 50))
#
# -------------------------------------------
# Time: 2019-10-31 13:25:55
# -------------------------------------------
# ('#bigil', 57)
# ('#atlee', 12)
# ('#srk', 12)
# ('#ai', 10)
# ('#shahrukhkhan', 9)
# ('#sanki', 9)
# ('#viswasam', 9)
# ('#hvinoth', 8)
# ('#halloween', 6)
# ('#bigdata', 5)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:26:00
# -------------------------------------------
# ('#bigil', 61)
# ('#atlee', 12)
# ('#srk', 12)
# ('#ai', 10)
# ('#shahrukhkhan', 9)
# ('#sanki', 9)
# ('#viswasam', 9)
# ('#hvinoth', 8)
# ('#halloween', 6)
# ('#bigdata', 5)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:26:05
# -------------------------------------------
# ('#bigil', 65)
# ('#atlee', 13)
# ('#srk', 12)
# ('#shahrukhkhan', 10)
# ('#ai', 10)
# ('#viswasam', 10)
# ('#sanki', 9)
# ('#hvinoth', 8)
# ('#halloween', 6)
# ('#bigdata', 5)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:26:10
# -------------------------------------------
# ('#bigil', 69)
# ('#atlee', 13)
# ('#ai', 13)
# ('#srk', 12)
# ('#viswasam', 12)
# ('#shahrukhkhan', 10)
# ('#sanki', 9)
# ('#hvinoth', 8)
# ('#petta', 7)
# ('#bigdata', 6)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:26:15
# -------------------------------------------
# ('#bigil', 79)
# ('#atlee', 16)
# ('#srk', 16)
# ('#ai', 15)
# ('#shahrukhkhan', 14)
# ('#viswasam', 13)
# ('#sanki', 12)
# ('#hvinoth', 9)
# ('#ongseongwu', 8)
# ('#petta', 8)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:26:20
# -------------------------------------------
# ('#bigil', 87)
# ('#atlee', 19)
# ('#srk', 18)
# ('#ai', 17)
# ('#sanki', 16)
# ('#shahrukhkhan', 15)
# ('#viswasam', 14)
# ('#hvinoth', 10)
# ('#ongseongwu', 9)
# ('#petta', 8)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:26:25
# -------------------------------------------
# ('#bigil', 102)
# ('#atlee', 20)
# ('#ai', 20)
# ('#srk', 19)
# ('#viswasam', 17)
# ('#shahrukhkhan', 16)
# ('#sanki', 16)
# ('#hvinoth', 11)
# ('#ongseongwu', 9)
# ('#petta', 9)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:26:30
# -------------------------------------------
# ('#bigil', 106)
# ('#atlee', 22)
# ('#srk', 21)
# ('#ai', 21)
# ('#sanki', 18)
# ('#viswasam', 17)
# ('#shahrukhkhan', 16)
# ('#hvinoth', 11)
# ('#ongseongwu', 9)
# ('#petta', 9)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:26:35
# -------------------------------------------
# ('#bigil', 110)
# ('#atlee', 23)
# ('#srk', 23)
# ('#ai', 21)
# ('#sanki', 20)
# ('#viswasam', 18)
# ('#shahrukhkhan', 16)
# ('#hvinoth', 11)
# ('#petta', 11)
# ('#ongseongwu', 10)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:26:40
# -------------------------------------------
# ('#bigil', 111)
# ('#atlee', 23)
# ('#srk', 23)
# ('#ai', 21)
# ('#sanki', 20)
# ('#viswasam', 18)
# ('#shahrukhkhan', 16)
# ('#hvinoth', 11)
# ('#petta', 11)
# ('#ongseongwu', 10)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:26:45
# -------------------------------------------
# ('#bigil', 112)
# ('#atlee', 25)
# ('#srk', 24)
# ('#ai', 22)
# ('#sanki', 21)
# ('#viswasam', 19)
# ('#shahrukhkhan', 17)
# ('#hvinoth', 12)
# ('#petta', 11)
# ('#ongseongwu', 10)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:26:50
# -------------------------------------------
# ('#bigil', 114)
# ('#atlee', 25)
# ('#srk', 25)
# ('#ai', 23)
# ('#sanki', 21)
# ('#viswasam', 19)
# ('#shahrukhkhan', 18)
# ('#hvinoth', 12)
# ('#petta', 11)
# ('#ongseongwu', 10)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:26:50
# -------------------------------------------
# ('movie', 226, datetime.datetime(2019, 10, 31, 13, 26, 50))
# ('good', 8, datetime.datetime(2019, 10, 31, 13, 26, 50))
# ('ai', 19, datetime.datetime(2019, 10, 31, 13, 26, 50))
# ('spark', 14, datetime.datetime(2019, 10, 31, 13, 26, 50))
# ('data', 4, datetime.datetime(2019, 10, 31, 13, 26, 50))
#
# -------------------------------------------
# Time: 2019-10-31 13:26:55
# -------------------------------------------
# ('#bigil', 122)
# ('#srk', 27)
# ('#atlee', 26)
# ('#ai', 23)
# ('#sanki', 22)
# ('#viswasam', 20)
# ('#shahrukhkhan', 18)
# ('#hvinoth', 13)
# ('#petta', 12)
# ('#ongseongwu', 10)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:27:00
# -------------------------------------------
# ('#bigil', 124)
# ('#atlee', 27)
# ('#srk', 27)
# ('#ai', 24)
# ('#sanki', 22)
# ('#viswasam', 20)
# ('#shahrukhkhan', 19)
# ('#hvinoth', 13)
# ('#petta', 12)
# ('#ongseongwu', 10)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:27:05
# -------------------------------------------
# ('#bigil', 126)
# ('#atlee', 27)
# ('#srk', 27)
# ('#ai', 24)
# ('#sanki', 22)
# ('#viswasam', 20)
# ('#shahrukhkhan', 19)
# ('#hvinoth', 13)
# ('#petta', 12)
# ('#ongseongwu', 10)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:27:10
# -------------------------------------------
# ('#bigil', 128)
# ('#srk', 29)
# ('#atlee', 28)
# ('#ai', 24)
# ('#sanki', 23)
# ('#shahrukhkhan', 21)
# ('#viswasam', 21)
# ('#hvinoth', 14)
# ('#petta', 12)
# ('#ongseongwu', 10)
# ...
# -------------------------------------------
# Time: 2019-10-31 13:27:15
# -------------------------------------------
# ('#bigil', 132)
# ('#srk', 29)
# ('#atlee', 28)
# ('#ai', 24)
# ('#sanki', 23)
# ('#viswasam', 22)
# ('#shahrukhkhan', 21)
# ('#hvinoth', 14)
# ('#petta', 13)
# ('#ongseongwu', 10)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:27:20
# -------------------------------------------
# ('#bigil', 136)
# ('#srk', 30)
# ('#atlee', 29)
# ('#ai', 25)
# ('#sanki', 24)
# ('#viswasam', 24)
# ('#shahrukhkhan', 21)
# ('#hvinoth', 16)
# ('#petta', 13)
# ('#ongseongwu', 10)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:27:25
# -------------------------------------------
# ('#bigil', 139)
# ('#atlee', 30)
# ('#srk', 30)
# ('#ai', 26)
# ('#sanki', 24)
# ('#viswasam', 24)
# ('#shahrukhkhan', 22)
# ('#hvinoth', 16)
# ('#petta', 13)
# ('#ongseongwu', 11)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:27:30
# -------------------------------------------
# ('#bigil', 143)
# ('#atlee', 33)
# ('#srk', 32)
# ('#ai', 30)
# ('#sanki', 26)
# ('#shahrukhkhan', 25)
# ('#viswasam', 24)
# ('#hvinoth', 16)
# ('#petta', 13)
# ('#ongseongwu', 11)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:27:35
# -------------------------------------------
# ('#bigil', 143)
# ('#atlee', 34)
# ('#srk', 34)
# ('#ai', 30)
# ('#sanki', 28)
# ('#shahrukhkhan', 25)
# ('#viswasam', 24)
# ('#hvinoth', 16)
# ('#petta', 13)
# ('#ongseongwu', 11)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:27:40
# -------------------------------------------
# ('#bigil', 145)
# ('#srk', 35)
# ('#atlee', 34)
# ('#ai', 30)
# ('#sanki', 28)
# ('#shahrukhkhan', 26)
# ('#viswasam', 24)
# ('#hvinoth', 16)
# ('#petta', 13)
# ('#ongseongwu', 11)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:27:45
# -------------------------------------------
# ('#bigil', 150)
# ('#atlee', 36)
# ('#srk', 36)
# ('#sanki', 31)
# ('#ai', 30)
# ('#shahrukhkhan', 27)
# ('#viswasam', 26)
# ('#hvinoth', 18)
# ('#petta', 13)
# ('#ongseongwu', 11)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:27:50
# -------------------------------------------
# ('#bigil', 153)
# ('#srk', 40)
# ('#atlee', 38)
# ('#sanki', 32)
# ('#ai', 31)
# ('#shahrukhkhan', 28)
# ('#viswasam', 26)
# ('#hvinoth', 18)
# ('#petta', 13)
# ('#ongseongwu', 11)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:27:50
# -------------------------------------------
# ('movie', 178, datetime.datetime(2019, 10, 31, 13, 27, 50))
# ('ai', 13, datetime.datetime(2019, 10, 31, 13, 27, 50))
# ('good', 4, datetime.datetime(2019, 10, 31, 13, 27, 50))
# ('spark', 18, datetime.datetime(2019, 10, 31, 13, 27, 50))
#
# -------------------------------------------
# Time: 2019-10-31 13:27:55
# -------------------------------------------
# ('#bigil', 155)
# ('#srk', 42)
# ('#atlee', 40)
# ('#sanki', 34)
# ('#ai', 32)
# ('#shahrukhkhan', 28)
# ('#viswasam', 26)
# ('#hvinoth', 18)
# ('#petta', 13)
# ('#halloween', 12)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:28:00
# -------------------------------------------
# ('#bigil', 162)
# ('#srk', 43)
# ('#atlee', 42)
# ('#sanki', 35)
# ('#ai', 33)
# ('#shahrukhkhan', 29)
# ('#viswasam', 26)
# ('#hvinoth', 18)
# ('#petta', 13)
# ('#halloween', 12)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:28:05
# -------------------------------------------
# ('#bigil', 170)
# ('#srk', 43)
# ('#atlee', 42)
# ('#sanki', 35)
# ('#ai', 34)
# ('#shahrukhkhan', 29)
# ('#viswasam', 28)
# ('#hvinoth', 19)
# ('#petta', 15)
# ('#halloween', 12)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:28:10
# -------------------------------------------
# ('#bigil', 175)
# ('#atlee', 48)
# ('#srk', 47)
# ('#sanki', 38)
# ('#ai', 37)
# ('#shahrukhkhan', 30)
# ('#viswasam', 29)
# ('#hvinoth', 20)
# ('#petta', 15)
# ('#halloween', 12)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:28:15
# -------------------------------------------
# ('#bigil', 179)
# ('#atlee', 48)
# ('#srk', 48)
# ('#sanki', 40)
# ('#ai', 37)
# ('#shahrukhkhan', 30)
# ('#viswasam', 29)
# ('#hvinoth', 20)
# ('#petta', 15)
# ('#ongseongwu', 12)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:28:20
# -------------------------------------------
# ('#bigil', 191)
# ('#atlee', 49)
# ('#srk', 48)
# ('#sanki', 41)
# ('#ai', 37)
# ('#shahrukhkhan', 31)
# ('#viswasam', 30)
# ('#hvinoth', 20)
# ('#petta', 16)
# ('#ongseongwu', 12)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:28:25
# -------------------------------------------
# ('#bigil', 198)
# ('#atlee', 51)
# ('#srk', 51)
# ('#sanki', 45)
# ('#ai', 37)
# ('#shahrukhkhan', 34)
# ('#viswasam', 31)
# ('#hvinoth', 21)
# ('#petta', 16)
# ('#halloween', 13)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:28:30
# -------------------------------------------
# ('#bigil', 206)
# ('#atlee', 52)
# ('#srk', 52)
# ('#sanki', 45)
# ('#ai', 37)
# ('#shahrukhkhan', 36)
# ('#viswasam', 32)
# ('#hvinoth', 22)
# ('#petta', 17)
# ('#halloween', 13)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:28:35
# -------------------------------------------
# ('#bigil', 209)
# ('#atlee', 54)
# ('#srk', 52)
# ('#sanki', 46)
# ('#ai', 38)
# ('#shahrukhkhan', 37)
# ('#viswasam', 32)
# ('#hvinoth', 22)
# ('#petta', 17)
# ('#halloween', 13)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:28:40
# -------------------------------------------
# ('#bigil', 212)
# ('#atlee', 54)
# ('#srk', 52)
# ('#sanki', 46)
# ('#ai', 38)
# ('#shahrukhkhan', 37)
# ('#viswasam', 32)
# ('#hvinoth', 22)
# ('#petta', 17)
# ('#halloween', 13)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:28:45
# -------------------------------------------
# ('#bigil', 214)
# ('#atlee', 55)
# ('#srk', 53)
# ('#sanki', 47)
# ('#ai', 40)
# ('#shahrukhkhan', 37)
# ('#viswasam', 32)
# ('#hvinoth', 22)
# ('#petta', 17)
# ('#ongseongwu', 13)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:28:50
# -------------------------------------------
# ('#bigil', 215)
# ('#atlee', 55)
# ('#srk', 53)
# ('#sanki', 47)
# ('#ai', 41)
# ('#shahrukhkhan', 37)
# ('#viswasam', 33)
# ('#hvinoth', 23)
# ('#petta', 17)
# ('#halloween', 14)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:28:50
# -------------------------------------------
# ('movie', 244, datetime.datetime(2019, 10, 31, 13, 28, 50))
# ('good', 10, datetime.datetime(2019, 10, 31, 13, 28, 50))
# ('ai', 10, datetime.datetime(2019, 10, 31, 13, 28, 50))
# ('spark', 11, datetime.datetime(2019, 10, 31, 13, 28, 50))
# ('data', 2, datetime.datetime(2019, 10, 31, 13, 28, 50))
#
# -------------------------------------------
# Time: 2019-10-31 13:28:55
# -------------------------------------------
# ('#bigil', 217)
# ('#atlee', 55)
# ('#srk', 54)
# ('#sanki', 47)
# ('#ai', 42)
# ('#shahrukhkhan', 38)
# ('#viswasam', 33)
# ('#hvinoth', 23)
# ('#petta', 17)
# ('#halloween', 14)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:29:00
# -------------------------------------------
# ('#bigil', 222)
# ('#atlee', 55)
# ('#srk', 55)
# ('#sanki', 48)
# ('#ai', 44)
# ('#shahrukhkhan', 38)
# ('#viswasam', 33)
# ('#hvinoth', 23)
# ('#petta', 17)
# ('#halloween', 14)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:29:05
# -------------------------------------------
# ('#bigil', 226)
# ('#atlee', 55)
# ('#srk', 55)
# ('#sanki', 48)
# ('#ai', 44)
# ('#shahrukhkhan', 38)
# ('#viswasam', 34)
# ('#hvinoth', 24)
# ('#petta', 17)
# ('#halloween', 14)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:29:10
# -------------------------------------------
# ('#bigil', 229)
# ('#atlee', 56)
# ('#srk', 56)
# ('#sanki', 49)
# ('#ai', 45)
# ('#shahrukhkhan', 38)
# ('#viswasam', 34)
# ('#hvinoth', 24)
# ('#petta', 17)
# ('#halloween', 15)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:29:15
# -------------------------------------------
# ('#bigil', 230)
# ('#atlee', 57)
# ('#srk', 57)
# ('#sanki', 49)
# ('#ai', 45)
# ('#shahrukhkhan', 40)
# ('#viswasam', 35)
# ('#hvinoth', 25)
# ('#petta', 17)
# ('#halloween', 16)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:29:20
# -------------------------------------------
# ('#bigil', 236)
# ('#atlee', 57)
# ('#srk', 57)
# ('#sanki', 49)
# ('#ai', 46)
# ('#shahrukhkhan', 40)
# ('#viswasam', 36)
# ('#hvinoth', 26)
# ('#petta', 17)
# ('#halloween', 16)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:29:25
# -------------------------------------------
# ('#bigil', 244)
# ('#atlee', 59)
# ('#srk', 59)
# ('#sanki', 51)
# ('#ai', 46)
# ('#shahrukhkhan', 40)
# ('#viswasam', 36)
# ('#hvinoth', 26)
# ('#petta', 17)
# ('#halloween', 16)
# ...
# -------------------------------------------
# Time: 2019-10-31 13:29:30
# -------------------------------------------
# ('#bigil', 246)
# ('#atlee', 61)
# ('#srk', 60)
# ('#sanki', 52)
# ('#ai', 47)
# ('#shahrukhkhan', 41)
# ('#viswasam', 37)
# ('#hvinoth', 27)
# ('#petta', 17)
# ('#halloween', 17)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:29:35
# -------------------------------------------
# ('#bigil', 257)
# ('#atlee', 63)
# ('#srk', 61)
# ('#sanki', 54)
# ('#ai', 49)
# ('#shahrukhkhan', 43)
# ('#viswasam', 38)
# ('#hvinoth', 27)
# ('#halloween', 20)
# ('#petta', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:29:40
# -------------------------------------------
# ('#bigil', 263)
# ('#atlee', 63)
# ('#srk', 61)
# ('#sanki', 54)
# ('#ai', 50)
# ('#shahrukhkhan', 43)
# ('#viswasam', 38)
# ('#hvinoth', 27)
# ('#halloween', 20)
# ('#petta', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:29:45
# -------------------------------------------
# ('#bigil', 265)
# ('#atlee', 63)
# ('#srk', 61)
# ('#sanki', 54)
# ('#ai', 50)
# ('#shahrukhkhan', 43)
# ('#viswasam', 38)
# ('#hvinoth', 27)
# ('#halloween', 20)
# ('#petta', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:29:50
# -------------------------------------------
# ('#bigil', 270)
# ('#atlee', 64)
# ('#srk', 61)
# ('#sanki', 54)
# ('#ai', 50)
# ('#shahrukhkhan', 44)
# ('#viswasam', 38)
# ('#hvinoth', 27)
# ('#halloween', 20)
# ('#petta', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:29:50
# -------------------------------------------
# ('movie', 209, datetime.datetime(2019, 10, 31, 13, 29, 50))
# ('ai', 15, datetime.datetime(2019, 10, 31, 13, 29, 50))
# ('good', 4, datetime.datetime(2019, 10, 31, 13, 29, 50))
# ('spark', 14, datetime.datetime(2019, 10, 31, 13, 29, 50))
# ('data', 1, datetime.datetime(2019, 10, 31, 13, 29, 50))
#
# -------------------------------------------
# Time: 2019-10-31 13:29:55
# -------------------------------------------
# ('#bigil', 273)
# ('#atlee', 66)
# ('#srk', 63)
# ('#sanki', 55)
# ('#ai', 51)
# ('#shahrukhkhan', 44)
# ('#viswasam', 38)
# ('#hvinoth', 27)
# ('#halloween', 20)
# ('#petta', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:30:00
# -------------------------------------------
# ('#bigil', 280)
# ('#atlee', 66)
# ('#srk', 63)
# ('#sanki', 55)
# ('#ai', 53)
# ('#shahrukhkhan', 44)
# ('#viswasam', 38)
# ('#hvinoth', 27)
# ('#halloween', 20)
# ('#petta', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:30:05
# -------------------------------------------
# ('#bigil', 291)
# ('#atlee', 70)
# ('#srk', 67)
# ('#sanki', 60)
# ('#ai', 54)
# ('#shahrukhkhan', 47)
# ('#viswasam', 41)
# ('#hvinoth', 28)
# ('#halloween', 21)
# ('#petta', 19)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:30:10
# -------------------------------------------
# ('#bigil', 293)
# ('#atlee', 70)
# ('#srk', 67)
# ('#sanki', 60)
# ('#ai', 55)
# ('#shahrukhkhan', 47)
# ('#viswasam', 41)
# ('#hvinoth', 28)
# ('#halloween', 21)
# ('#petta', 19)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:30:15
# -------------------------------------------
# ('#bigil', 297)
# ('#atlee', 70)
# ('#srk', 67)
# ('#sanki', 60)
# ('#ai', 56)
# ('#shahrukhkhan', 47)
# ('#viswasam', 41)
# ('#hvinoth', 28)
# ('#halloween', 22)
# ('#petta', 19)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:30:20
# -------------------------------------------
# ('#bigil', 299)
# ('#atlee', 70)
# ('#srk', 68)
# ('#sanki', 61)
# ('#ai', 57)
# ('#shahrukhkhan', 48)
# ('#viswasam', 42)
# ('#hvinoth', 29)
# ('#halloween', 22)
# ('#petta', 19)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:30:25
# -------------------------------------------
# ('#bigil', 306)
# ('#atlee', 71)
# ('#srk', 69)
# ('#sanki', 61)
# ('#ai', 59)
# ('#shahrukhkhan', 50)
# ('#viswasam', 43)
# ('#hvinoth', 30)
# ('#halloween', 22)
# ('#petta', 19)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:30:30
# -------------------------------------------
# ('#bigil', 308)
# ('#atlee', 72)
# ('#srk', 70)
# ('#ai', 64)
# ('#sanki', 62)
# ('#shahrukhkhan', 50)
# ('#viswasam', 43)
# ('#hvinoth', 30)
# ('#halloween', 23)
# ('#petta', 19)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:30:35
# -------------------------------------------
# ('#bigil', 310)
# ('#atlee', 73)
# ('#srk', 71)
# ('#ai', 67)
# ('#sanki', 62)
# ('#shahrukhkhan', 50)
# ('#viswasam', 43)
# ('#hvinoth', 30)
# ('#halloween', 24)
# ('#petta', 20)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:30:40
# -------------------------------------------
# ('#bigil', 315)
# ('#atlee', 73)
# ('#srk', 71)
# ('#ai', 68)
# ('#sanki', 62)
# ('#shahrukhkhan', 50)
# ('#viswasam', 46)
# ('#hvinoth', 33)
# ('#halloween', 24)
# ('#petta', 20)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:30:45
# -------------------------------------------
# ('#bigil', 319)
# ('#atlee', 75)
# ('#srk', 72)
# ('#ai', 70)
# ('#sanki', 64)
# ('#shahrukhkhan', 51)
# ('#viswasam', 50)
# ('#hvinoth', 34)
# ('#halloween', 24)
# ('#petta', 22)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:30:50
# -------------------------------------------
# ('#bigil', 324)
# ('#atlee', 76)
# ('#srk', 75)
# ('#ai', 70)
# ('#sanki', 65)
# ('#shahrukhkhan', 52)
# ('#viswasam', 51)
# ('#hvinoth', 34)
# ('#halloween', 24)
# ('#petta', 22)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:30:50
# -------------------------------------------
# ('movie', 207, datetime.datetime(2019, 10, 31, 13, 30, 50))
# ('good', 9, datetime.datetime(2019, 10, 31, 13, 30, 50))
# ('ai', 37, datetime.datetime(2019, 10, 31, 13, 30, 50))
# ('spark', 8, datetime.datetime(2019, 10, 31, 13, 30, 50))
# ('data', 5, datetime.datetime(2019, 10, 31, 13, 30, 50))
#
# -------------------------------------------
# Time: 2019-10-31 13:30:55
# -------------------------------------------
# ('#bigil', 325)
# ('#atlee', 77)
# ('#srk', 75)
# ('#ai', 70)
# ('#sanki', 65)
# ('#shahrukhkhan', 53)
# ('#viswasam', 52)
# ('#hvinoth', 35)
# ('#halloween', 24)
# ('#petta', 22)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:31:00
# -------------------------------------------
# ('#bigil', 330)
# ('#atlee', 78)
# ('#srk', 75)
# ('#ai', 72)
# ('#sanki', 65)
# ('#shahrukhkhan', 54)
# ('#viswasam', 52)
# ('#hvinoth', 35)
# ('#halloween', 24)
# ('#petta', 22)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:31:05
# -------------------------------------------
# ('#bigil', 331)
# ('#atlee', 80)
# ('#srk', 76)
# ('#ai', 72)
# ('#sanki', 67)
# ('#shahrukhkhan', 55)
# ('#viswasam', 53)
# ('#hvinoth', 36)
# ('#halloween', 24)
# ('#petta', 22)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:31:10
# -------------------------------------------
# ('#bigil', 333)
# ('#atlee', 80)
# ('#srk', 76)
# ('#ai', 74)
# ('#sanki', 67)
# ('#shahrukhkhan', 55)
# ('#viswasam', 53)
# ('#hvinoth', 36)
# ('#halloween', 24)
# ('#petta', 22)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:31:15
# -------------------------------------------
# ('#bigil', 339)
# ('#atlee', 82)
# ('#srk', 78)
# ('#ai', 74)
# ('#sanki', 69)
# ('#shahrukhkhan', 55)
# ('#viswasam', 55)
# ('#hvinoth', 37)
# ('#halloween', 25)
# ('#petta', 23)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:31:20
# -------------------------------------------
# ('#bigil', 345)
# ('#atlee', 83)
# ('#srk', 79)
# ('#ai', 75)
# ('#sanki', 70)
# ('#viswasam', 57)
# ('#shahrukhkhan', 55)
# ('#hvinoth', 37)
# ('#halloween', 26)
# ('#petta', 24)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:31:25
# -------------------------------------------
# ('#bigil', 347)
# ('#atlee', 83)
# ('#srk', 79)
# ('#ai', 77)
# ('#sanki', 70)
# ('#viswasam', 57)
# ('#shahrukhkhan', 55)
# ('#hvinoth', 37)
# ('#halloween', 27)
# ('#petta', 24)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:31:30
# -------------------------------------------
# ('#bigil', 347)
# ('#atlee', 84)
# ('#srk', 81)
# ('#ai', 77)
# ('#sanki', 72)
# ('#viswasam', 58)
# ('#shahrukhkhan', 55)
# ('#hvinoth', 38)
# ('#halloween', 27)
# ('#petta', 24)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:31:35
# -------------------------------------------
# ('#bigil', 350)
# ('#atlee', 84)
# ('#srk', 81)
# ('#ai', 77)
# ('#sanki', 72)
# ('#viswasam', 59)
# ('#shahrukhkhan', 55)
# ('#hvinoth', 38)
# ('#halloween', 27)
# ('#petta', 24)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:31:40
# -------------------------------------------
# ('#bigil', 355)
# ('#atlee', 84)
# ('#srk', 81)
# ('#ai', 77)
# ('#sanki', 72)
# ('#viswasam', 59)
# ('#shahrukhkhan', 55)
# ('#hvinoth', 38)
# ('#halloween', 27)
# ('#petta', 24)
# ...
# -------------------------------------------
# Time: 2019-10-31 13:31:45
# -------------------------------------------
# ('#bigil', 362)
# ('#atlee', 85)
# ('#srk', 82)
# ('#ai', 78)
# ('#sanki', 73)
# ('#viswasam', 59)
# ('#shahrukhkhan', 55)
# ('#hvinoth', 38)
# ('#halloween', 27)
# ('#petta', 24)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:31:50
# -------------------------------------------
# ('#bigil', 366)
# ('#atlee', 85)
# ('#srk', 83)
# ('#ai', 78)
# ('#sanki', 73)
# ('#viswasam', 60)
# ('#shahrukhkhan', 56)
# ('#hvinoth', 38)
# ('#halloween', 27)
# ('#petta', 24)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:31:55
# -------------------------------------------
# ('#bigil', 372)
# ('#atlee', 86)
# ('#srk', 85)
# ('#ai', 80)
# ('#sanki', 74)
# ('#viswasam', 63)
# ('#shahrukhkhan', 59)
# ('#hvinoth', 39)
# ('#halloween', 28)
# ('#petta', 25)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:32:00
# -------------------------------------------
# ('#bigil', 381)
# ('#atlee', 89)
# ('#srk', 86)
# ('#ai', 82)
# ('#sanki', 75)
# ('#viswasam', 63)
# ('#shahrukhkhan', 61)
# ('#hvinoth', 39)
# ('#halloween', 28)
# ('#petta', 25)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:32:05
# -------------------------------------------
# ('#bigil', 389)
# ('#atlee', 89)
# ('#srk', 86)
# ('#ai', 82)
# ('#sanki', 75)
# ('#viswasam', 64)
# ('#shahrukhkhan', 61)
# ('#hvinoth', 40)
# ('#halloween', 28)
# ('#petta', 25)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:32:10
# -------------------------------------------
# ('#bigil', 399)
# ('#atlee', 91)
# ('#srk', 87)
# ('#ai', 82)
# ('#sanki', 77)
# ('#viswasam', 64)
# ('#shahrukhkhan', 62)
# ('#hvinoth', 40)
# ('#halloween', 28)
# ('#petta', 25)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:32:15
# -------------------------------------------
# ('#bigil', 406)
# ('#atlee', 91)
# ('#srk', 87)
# ('#ai', 83)
# ('#sanki', 77)
# ('#viswasam', 64)
# ('#shahrukhkhan', 63)
# ('#hvinoth', 40)
# ('#halloween', 28)
# ('#petta', 25)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:32:20
# -------------------------------------------
# ('#bigil', 412)
# ('#atlee', 92)
# ('#srk', 87)
# ('#ai', 84)
# ('#sanki', 77)
# ('#viswasam', 65)
# ('#shahrukhkhan', 64)
# ('#hvinoth', 40)
# ('#halloween', 28)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:32:25
# -------------------------------------------
# ('#bigil', 413)
# ('#atlee', 92)
# ('#srk', 88)
# ('#ai', 84)
# ('#sanki', 77)
# ('#viswasam', 67)
# ('#shahrukhkhan', 65)
# ('#hvinoth', 41)
# ('#halloween', 28)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:32:30
# -------------------------------------------
# ('#bigil', 416)
# ('#atlee', 93)
# ('#srk', 88)
# ('#ai', 84)
# ('#sanki', 77)
# ('#viswasam', 67)
# ('#shahrukhkhan', 66)
# ('#hvinoth', 41)
# ('#halloween', 28)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:32:35
# -------------------------------------------
# ('#bigil', 421)
# ('#atlee', 96)
# ('#srk', 88)
# ('#ai', 84)
# ('#sanki', 78)
# ('#viswasam', 70)
# ('#shahrukhkhan', 68)
# ('#hvinoth', 43)
# ('#halloween', 28)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:32:40
# -------------------------------------------
# ('#bigil', 426)
# ('#atlee', 98)
# ('#srk', 88)
# ('#ai', 84)
# ('#sanki', 79)
# ('#shahrukhkhan', 70)
# ('#viswasam', 70)
# ('#hvinoth', 43)
# ('#halloween', 28)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:32:45
# -------------------------------------------
# ('#bigil', 427)
# ('#atlee', 98)
# ('#srk', 88)
# ('#ai', 84)
# ('#sanki', 79)
# ('#shahrukhkhan', 70)
# ('#viswasam', 70)
# ('#hvinoth', 43)
# ('#halloween', 28)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:32:50
# -------------------------------------------
# ('#bigil', 434)
# ('#atlee', 99)
# ('#srk', 89)
# ('#ai', 85)
# ('#sanki', 80)
# ('#viswasam', 71)
# ('#shahrukhkhan', 70)
# ('#hvinoth', 44)
# ('#halloween', 29)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:32:55
# -------------------------------------------
# ('#bigil', 440)
# ('#atlee', 99)
# ('#srk', 90)
# ('#ai', 85)
# ('#sanki', 80)
# ('#viswasam', 72)
# ('#shahrukhkhan', 71)
# ('#hvinoth', 45)
# ('#halloween', 30)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:33:00
# -------------------------------------------
# ('#bigil', 442)
# ('#atlee', 99)
# ('#srk', 90)
# ('#ai', 85)
# ('#sanki', 81)
# ('#viswasam', 72)
# ('#shahrukhkhan', 71)
# ('#hvinoth', 45)
# ('#halloween', 30)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:33:05
# -------------------------------------------
# ('#bigil', 447)
# ('#atlee', 100)
# ('#srk', 93)
# ('#ai', 87)
# ('#sanki', 83)
# ('#viswasam', 72)
# ('#shahrukhkhan', 71)
# ('#hvinoth', 45)
# ('#halloween', 30)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:33:10
# -------------------------------------------
# ('#bigil', 451)
# ('#atlee', 100)
# ('#srk', 95)
# ('#ai', 88)
# ('#sanki', 84)
# ('#shahrukhkhan', 72)
# ('#viswasam', 72)
# ('#hvinoth', 45)
# ('#halloween', 30)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:33:15
# -------------------------------------------
# ('#bigil', 462)
# ('#atlee', 100)
# ('#srk', 96)
# ('#ai', 88)
# ('#sanki', 85)
# ('#viswasam', 75)
# ('#shahrukhkhan', 72)
# ('#hvinoth', 47)
# ('#halloween', 31)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:33:20
# -------------------------------------------
# ('#bigil', 463)
# ('#atlee', 100)
# ('#srk', 96)
# ('#ai', 89)
# ('#sanki', 85)
# ('#viswasam', 75)
# ('#shahrukhkhan', 72)
# ('#hvinoth', 47)
# ('#halloween', 31)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:33:25
# -------------------------------------------
# ('#bigil', 471)
# ('#atlee', 100)
# ('#srk', 96)
# ('#ai', 92)
# ('#sanki', 85)
# ('#viswasam', 75)
# ('#shahrukhkhan', 72)
# ('#hvinoth', 47)
# ('#halloween', 31)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:33:30
# -------------------------------------------
# ('#bigil', 473)
# ('#atlee', 101)
# ('#srk', 96)
# ('#ai', 93)
# ('#sanki', 85)
# ('#viswasam', 76)
# ('#shahrukhkhan', 73)
# ('#hvinoth', 48)
# ('#halloween', 31)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:33:35
# -------------------------------------------
# ('#bigil', 475)
# ('#atlee', 102)
# ('#srk', 96)
# ('#ai', 93)
# ('#sanki', 86)
# ('#viswasam', 77)
# ('#shahrukhkhan', 74)
# ('#hvinoth', 48)
# ('#halloween', 31)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:33:40
# -------------------------------------------
# ('#bigil', 480)
# ('#atlee', 102)
# ('#srk', 96)
# ('#ai', 93)
# ('#sanki', 86)
# ('#viswasam', 77)
# ('#shahrukhkhan', 74)
# ('#hvinoth', 48)
# ('#halloween', 31)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:33:45
# -------------------------------------------
# ('#bigil', 481)
# ('#atlee', 106)
# ('#srk', 98)
# ('#ai', 93)
# ('#sanki', 88)
# ('#viswasam', 77)
# ('#shahrukhkhan', 76)
# ('#hvinoth', 48)
# ('#halloween', 31)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:33:50
# -------------------------------------------
# ('#bigil', 483)
# ('#atlee', 106)
# ('#srk', 98)
# ('#ai', 94)
# ('#sanki', 88)
# ('#viswasam', 80)
# ('#shahrukhkhan', 76)
# ('#hvinoth', 49)
# ('#halloween', 31)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:33:55
# -------------------------------------------
# ('#bigil', 487)
# ('#atlee', 108)
# ('#srk', 99)
# ('#ai', 94)
# ('#sanki', 90)
# ('#viswasam', 84)
# ('#shahrukhkhan', 77)
# ('#hvinoth', 50)
# ('#halloween', 32)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:34:00
# -------------------------------------------
# ('#bigil', 490)
# ('#atlee', 110)
# ('#srk', 100)
# ('#ai', 95)
# ('#sanki', 91)
# ('#viswasam', 85)
# ('#shahrukhkhan', 78)
# ('#hvinoth', 50)
# ('#halloween', 33)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:34:05
# -------------------------------------------
# ('#bigil', 493)
# ('#atlee', 110)
# ('#srk', 100)
# ('#ai', 96)
# ('#sanki', 91)
# ('#viswasam', 85)
# ('#shahrukhkhan', 78)
# ('#hvinoth', 50)
# ('#halloween', 33)
# ('#petta', 26)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:34:10
# -------------------------------------------
# ('#bigil', 502)
# ('#atlee', 111)
# ('#srk', 101)
# ('#ai', 98)
# ('#sanki', 92)
# ('#viswasam', 85)
# ('#shahrukhkhan', 78)
# ('#hvinoth', 50)
# ('#halloween', 33)
# ('#petta', 26)
# ...
# -------------------------------------------
# Time: 2019-10-31 13:34:15
# -------------------------------------------
# ('#bigil', 508)
# ('#atlee', 112)
# ('#srk', 103)
# ('#ai', 101)
# ('#sanki', 93)
# ('#viswasam', 86)
# ('#shahrukhkhan', 80)
# ('#hvinoth', 50)
# ('#halloween', 33)
# ('#petta', 27)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:34:20
# -------------------------------------------
# ('#bigil', 508)
# ('#atlee', 112)
# ('#srk', 103)
# ('#ai', 101)
# ('#sanki', 93)
# ('#viswasam', 86)
# ('#shahrukhkhan', 80)
# ('#hvinoth', 50)
# ('#halloween', 33)
# ('#petta', 27)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:34:25
# -------------------------------------------
# ('#bigil', 512)
# ('#atlee', 112)
# ('#srk', 105)
# ('#ai', 102)
# ('#sanki', 94)
# ('#viswasam', 86)
# ('#shahrukhkhan', 83)
# ('#hvinoth', 50)
# ('#halloween', 33)
# ('#petta', 27)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:34:30
# -------------------------------------------
# ('#bigil', 516)
# ('#atlee', 114)
# ('#ai', 108)
# ('#srk', 105)
# ('#sanki', 95)
# ('#viswasam', 87)
# ('#shahrukhkhan', 85)
# ('#hvinoth', 51)
# ('#halloween', 33)
# ('#artificialintelligence', 28)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:34:35
# -------------------------------------------
# ('#bigil', 519)
# ('#atlee', 117)
# ('#ai', 110)
# ('#srk', 106)
# ('#sanki', 96)
# ('#shahrukhkhan', 87)
# ('#viswasam', 87)
# ('#hvinoth', 51)
# ('#halloween', 34)
# ('#artificialintelligence', 28)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:34:40
# -------------------------------------------
# ('#bigil', 524)
# ('#atlee', 117)
# ('#ai', 113)
# ('#srk', 106)
# ('#sanki', 96)
# ('#viswasam', 91)
# ('#shahrukhkhan', 87)
# ('#hvinoth', 53)
# ('#halloween', 34)
# ('#petta', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:34:45
# -------------------------------------------
# ('#bigil', 528)
# ('#atlee', 118)
# ('#ai', 116)
# ('#srk', 107)
# ('#sanki', 97)
# ('#viswasam', 91)
# ('#shahrukhkhan', 89)
# ('#hvinoth', 53)
# ('#halloween', 34)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:34:50
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:34:55
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:35:00
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:35:05
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:35:10
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:35:15
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:35:20
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:35:25
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:35:30
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:35:35
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:35:40
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:35:45
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:35:50
# -------------------------------------------
# ('#bigil', 531)
# ('#atlee', 121)
# ('#ai', 117)
# ('#srk', 108)
# ('#sanki', 98)
# ('#shahrukhkhan', 91)
# ('#viswasam', 91)
# ('#hvinoth', 53)
# ('#halloween', 35)
# ('#artificialintelligence', 29)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 13:35:50
# -------------------------------------------
